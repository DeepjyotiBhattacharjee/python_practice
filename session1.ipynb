# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
print("Data", "Science", "Mentorship", "Program", "By", "CampusX", sep="-")
# Out:
# Data-Science-Mentorship-Program-By-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
# c/5 = (f-32)/9
# f = 9c/5 + 32

c = float(input("enter temperature in celsius : "))
f = (9*c/5) + 32
print(f"{c} degree celsius = {f} degree fahrenheit")
# Out:
# 27.0 degree celsius = 80.6 degree fahrenheit

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
a = int(input("enter first number : "))
b = int(input("enter second number : "))

temp = a
a = b
b = temp

print("a = ",a)
print("b = ",b)
# Out:
# a =  3
# b =  2

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
x1 = 2
y1 = 3

x2 = 4
y2 = 5

d = ((x2-x1)**2 + (y2-y1)**2)**0.5
print(d)
# Out:
# 2.8284271247461903

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
principal = float(input("Enter the principal amount"))
rate = float(input("Enter the rate of interest"))
time = float(input("Enter the time period"))

print("Simple interest = ",(principal*rate*time/100))
# Out:
# Simple interest =  715000.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
heads = int(input("enter the number of heads : "))
legs = int(input("enter the number of legs : "))

# h = c+d
# l = 2c + 4d
#2h = 2c + 2d
#l-2h = 2d
#d = l/2 - h ---- 1

# l = 2c + 4d
# 4h =4c + 4d
# 4h-l = 2c
#c = 2h-l/2 ------ 2

c = (2*heads) - (legs//2)
d = (legs//2) - heads

print("number of chickens = ",c)
print("number of dogs = ",d)
# Out:
# number of chickens =  2
# number of dogs =  2

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
n = int(input("upto what number to you want to get the sum of squares?"))

print(f"sum of squares till {n} = ",(n*(n+1)*(2*n+1))/6)
# Out:
# sum of squares till 4 =  30.0

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
a = int(input("Enter first term of AP"))
b = int(input("Enter second term of AP"))
n = int(input("Which term do you want of the series ? "))
d = b-a

print(f"the {n}th term of the AP = ",(a+(n-1)*d))
# Out:
# the 100th term of the AP =  100

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
# fraction 1

n1 = int(input("enter numerator of first fraction"))
d1 = int(input("enter denominator of first fraction"))


n2 = int(input("enter numerator of second fraction"))
d2 = int(input("enter denominator of second fraction"))

total = (n2*d1 + n1*d2)/(d1*d2)

print(f" {n1}/{d1} + {n2}/{d2} =  ",(n2*d1 + n1*d2),"/",(d1*d2))
# Out:
#  1/2 + 3/4 =   10 / 8

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# milk tank
H = float(input("enter height of milk tank "))
L = float(input("enter length of milk tank "))
B = float(input("enter breadth of milk tank "))

milk_v = H*B*L

# glass
h = float(input("enter height of glass "))
r = float(input("enter radius of glass "))

pi = 22/7

glass_v = pi * r**2 * h

print("number of glasses = ",round(milk_v/glass_v))
# Out:
# number of glasses =  32
